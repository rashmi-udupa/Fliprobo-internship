# %% [markdown]
# # Sarees

# %%
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

# %%
import requests

# %%
#!pip install selenium

# %%
# Function to get url
def get_url(url):
    driver=webdriver.Chrome('D:\chromedriver_win32\chromedriver.exe')
    page=driver.get(url)
    images=driver.find_elements_by_xpath("//img[@class='_2r_T1I']")
    urls=[]
    for image in images:
        source=image.get_attribute('src')
        urls.append(source)
        print(source)
    return urls

# %%
url1='https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo,8on,zpd,9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees'
url2="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=2"
url3="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=3"
url4="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=4"
url5="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=5"
url6="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=6"
url7="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=7"
url8="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=8"
url9="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=9"
url10="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=10"
url11="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=11"
url12="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=12"
url13="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=13"
url14="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=14"
url15="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=15"
url16="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=16"
url17="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=17"
url18="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=18"
url19="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=19"
url20="https://www.flipkart.com/clothing-and-accessories/saree-and-accessories/saree/women-saree/pr?sid=clo%2C8on%2Czpd%2C9og&otracker=categorytree&otracker=nmenu_sub_Women_0_Sarees&page=20"

# %%
urllist=get_url(url1)+get_url(url2)+get_url(url3)+get_url(url4)+get_url(url5)+get_url(url6)+get_url(url7)+get_url(url8)+get_url(url9)+get_url(url10)+get_url(url11)+get_url(url12)+get_url(url13)+get_url(url14)+get_url(url15)+get_url(url16)+get_url(url17)+get_url(url18)+get_url(url19)+get_url(url20)
# Out:
# https://rukminim1.flixcart.com/image/330/396/k0tw13k0/sari/h/z/b/free-velet-blue-marutinandan-nx-original-imafhysdphb2ngpj.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kctf0cw0/sari/x/t/s/free-wine-saree-crally-unstitched-original-imaftugazhhzjhxr.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k6fd47k0pkrrdj/sari/n/j/u/green-beige-red-yellow-1363sj505-1399sj503-siril-original-imafntm5uvc8jyg2.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k12go7k0/sari/p/h/c/free-bd030-bollydoll-designer-original-imafgjen5kwbudbm.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k6fd47k0pkrrdj/sari/h/f/u/red-yellow-blue-1363sj505-1363sj506-siril-original-imafzxgemkybhus7.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kfpq5jk0-0/sari/z/i/n/free-hnc000120-hnc-retail-unstitched-original-imaf6qqasxhsthad.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k6gsk280/sari/s/z/k/free-die-mor-pink-dynamic-import-export-original-imaf7yhpmd98jth2.jpeg?q=50
# ...

# %%
len(urllist)
# Out:
# 800

# %%
#### to download images

# %%
for index,link in enumerate(urllist):
    print(f"Downloading {index+1} of {len(urllist)}")
    response=requests.get(link)
    with open(f"E:/Data Science/FlipRobo/Assignments/Deep Learning/Images/Image Scraping and Classification Project/Sarees/Img_{index}.jpeg",'wb') as file:
        file.write(response.content)

# %% [markdown]
# # Trousers
#
# Image class is same as saree so only urls will change. So we can use same function to extract urls

# %%
url_t1="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal%20Trousers"
url_t2="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=2"
url_t3="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=3"
url_t4="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=4"
url_t5="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=5"
url_t6="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=6"
url_t7="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=7"
url_t8="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=8"
url_t9="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=9"
url_t10="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=10"
url_t11="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=11"
url_t12="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=12"
url_t13="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=13"
url_t14="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=14"
url_t15="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=15"
url_t16="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=16"
url_t17="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=17"
url_t18="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=18"
url_t19="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=19"
url_t20="https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal+Trousers&page=20"

# %%
trouser_list=get_url(url_t1)+get_url(url_t2)+get_url(url_t3)+get_url(url_t4)+get_url(url_t5)+get_url(url_t6)+get_url(url_t7)+get_url(url_t8)+get_url(url_t9)+get_url(url_t10)+get_url(url_t11)+get_url(url_t12)+get_url(url_t13)+get_url(url_t14)+get_url(url_t15)+get_url(url_t16)+get_url(url_t17)+get_url(url_t18)+get_url(url_t19)+get_url(url_t20)
len(trouser_list)
# Out:
# https://rukminim1.flixcart.com/image/330/396/jvv9zm80/trouser/g/z/c/34-combo-panta-black-maroon-2435-vandnam-fabrics-original-imafgzcwdjhswe4x.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k7gikcw0/trouser/z/g/b/38-new-combo-classio-fashion-original-imafpzz8yjgxckfg.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kixgtjk0-0/trouser/j/j/l/32-petfwnsp649383-peter-england-original-imafymfxqqnjet3e.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kfoapow0-0/trouser/7/p/g/28-formal-blue-classio-original-imafw2jxuevz5wxv.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/ki6bgcw0-0/trouser/x/g/9/32-petfonspu88155-peter-england-original-imafyf2zszfcshg4.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kfoapow0-0/trouser/v/x/5/38-t-130-trouser-baleno-black-aa-ad-av-original-imafw2jugbuxmnq9.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/khmbafk0-0/trouser/0/y/t/32-pctfosspy01076-peter-england-original-imafxhepytbyaha4.jpeg?q=50
# ...

# %%
#### dowloading images
for index, link in enumerate(trouser_list):
    print(f"downloading {index+1} image")
    response=requests.get(link)
    with open(f"E:/Data Science/FlipRobo/Assignments/Deep Learning/Images/Image Scraping and Classification Project/Trousers/Img{index}.jpeg",'wb') as file:
        file.write(response.content)
# Out:
# downloading 1 image
# downloading 2 image
# downloading 3 image
# downloading 4 image
# downloading 5 image
# downloading 6 image
# downloading 7 image
# downloading 8 image
# downloading 9 image
# downloading 10 image
# downloading 11 image
# downloading 12 image
# downloading 13 image
# downloading 14 image
# downloading 15 image
# downloading 16 image
# downloading 17 image
# downloading 18 image
# downloading 19 image
# downloading 20 image
# downloading 21 image
# downloading 22 image
# downloading 23 image
# downloading 24 image
# downloading 25 image
# downloading 26 image
# downloading 27 image
# downloading 28 image
# downloading 29 image
# downloading 30 image
# downloading 31 image
# downloading 32 image
# downloading 33 image
# downloading 34 image
# downloading 35 image
# downloading 36 image
# downloading 37 image
# downloading 38 image
# downloading 39 image
# downloading 40 image
# downloading 41 image
# downloading 42 image
# downloading 43 image
# ...

# %% [markdown]
# # Jeans
# Jeans also same attribute. So we can use the same function

# %%
url_j1="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo,vua,k58,i51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans"
url_j2="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=2"
url_j3="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=3"
url_j4="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=4"
url_j5="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=5"
url_j6="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=6"
url_j7="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=7"
url_j8="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=8"
url_j9="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=9"
url_j10="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=10"
url_j11="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=11"
url_j12="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=12"
url_j13="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=13"
url_j14="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=14"
url_j15="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=15"
url_j16="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=16"
url_j17="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=17"
url_j18="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=18"
url_j19="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=19"
url_j20="https://www.flipkart.com/clothing-and-accessories/bottomwear/jeans/men-jeans/pr?sid=clo%2Cvua%2Ck58%2Ci51&otracker=categorytree&otracker=nmenu_sub_Men_0_Jeans&page=20"

# %%
jean_url=get_url(url_j1)+get_url(url_j2)+get_url(url_j3)+get_url(url_j4)+get_url(url_j5)+get_url(url_j6)+get_url(url_j7)+get_url(url_j8)+get_url(url_j9)+get_url(url_j10)+get_url(url_j11)+get_url(url_j12)+get_url(url_j13)+get_url(url_j14)+get_url(url_j15)+get_url(url_j16)+get_url(url_j17)+get_url(url_j18)+get_url(url_j19)+get_url(url_j20)
# Out:
# https://rukminim1.flixcart.com/image/330/396/kg2l47k0-0/jean/z/k/h/36-lj3127-lzard-original-imafwdxzcxy54wys.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kfoapow0-0/jean/v/k/h/34-jeancns-front-lgreybla-urbano-fashion-original-imafw37y3fmhvyqy.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/jh6l2fk0/jean/4/a/z/30-lj183a-lzard-original-imaf5883mb8vchhb.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/kj4m0sw0-0/jean/0/c/8/32-fmjno1238-flying-machine-original-imafyrfhjrfake3q.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/jjylw280/jean/p/a/s/34-eps-black-03-urbano-fashion-original-imaf7f7wyy7sv6zk.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/k4x2du80/jean/g/a/r/32-bss20d003-billion-original-imafnpvd2k7dgadz.jpeg?q=50
# https://rukminim1.flixcart.com/image/330/396/jhavdzk0/jean/j/x/p/30-hpsjogger-lgrey-urbano-fashion-original-imaf5bzbhhvwu9by.jpeg?q=50
# ...

# %%
len(jean_url)
# Out:
# 800

# %%
#### dowloading images
for index, link in enumerate(jean_url):
    print(f"downloading {index+1} image")
    response=requests.get(link)
    with open(f"E:/Data Science/FlipRobo/Assignments/Deep Learning/Images/Image Scraping and Classification Project/Jeans/Img{index}.jpeg",'wb') as file:
        file.write(response.content)
# Out:
# downloading 1 image
# downloading 2 image
# downloading 3 image
# downloading 4 image
# downloading 5 image
# downloading 6 image
# downloading 7 image
# downloading 8 image
# downloading 9 image
# downloading 10 image
# downloading 11 image
# downloading 12 image
# downloading 13 image
# downloading 14 image
# downloading 15 image
# downloading 16 image
# downloading 17 image
# downloading 18 image
# downloading 19 image
# downloading 20 image
# downloading 21 image
# downloading 22 image
# downloading 23 image
# downloading 24 image
# downloading 25 image
# downloading 26 image
# downloading 27 image
# downloading 28 image
# downloading 29 image
# downloading 30 image
# downloading 31 image
# downloading 32 image
# downloading 33 image
# downloading 34 image
# downloading 35 image
# downloading 36 image
# downloading 37 image
# downloading 38 image
# downloading 39 image
# downloading 40 image
# downloading 41 image
# downloading 42 image
# downloading 43 image
# ...

# %% [markdown]
# ## Downloading all images are done
